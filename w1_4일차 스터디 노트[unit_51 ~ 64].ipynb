# %% [markdown]
# # ⚡️study by 석민⚡️

# %% [markdown]
# # 51_[연습문제] 연산자(04)

# %% [markdown]
# - 고도가 60m 올라갈 때마다 기온이 0.8도 내려 간다고 할 때 고도를 입력하면
# - 기온이 출력되는 프로그램을 만들어 보자.(지면온도: 29도)

# %% [markdown]
# # 높이 문제와 유사한 문제들
# ~~~python
# if input_h % height != 0:
#     result -= h_temp
# ~~~
# # 이처럼 딱 떨어지지 않고 남는경우 한번더 빼줘야 한다.

# %%
base_temp = 29
height = 60
h_temp = 0.8

input_h = int(input("고도 입력: "))

result = 29 - ((input_h // 60) * 0.8)

if input_h % height != 0:
    result -= h_temp

print(f"지면 온도: {base_temp}")
print(f"고도 {input_h}m의 기온: {result}")
# Out:
# 고도 입력: 720
# 지면 온도: 29
# 고도 720m의 기온: 19.4

# %% [markdown]
# - 197개의 빵과 152개의 우유를 17명의 학생한테 동일하게 나눠 준다고 할 때,
# - 한 명의 학생이 갖게 되는 빵과 우유 개수를 구하고 남는 빵과 우유 개수를 출력하자.

# %%
bread = 197
milk = 152
stu = 17

# 입력
print(f"학생 한명이 갖게되는 빵 개수: {bread // stu}")
print(f"학생 한명이 갖게되는 우유 개수: {milk // stu}")

# 출력
print(f"남은 빵 개수: {bread % stu}")
print(f"남은 우유 개수: {milk % stu}")
# Out:
# 학생 한명이 갖게되는 빵 개수: 11
# 학생 한명이 갖게되는 우유 개수: 8
# 남은 빵 개수: 10
# 남은 우유 개수: 16

# %% [markdown]
# # 52_[연습문제] 연산자(05)

# %% [markdown]
# - 다음 내용을 참고해서 백신 접종 대상자를 구분하기 위한 프로그램을 만들어 보자.

# %%
age = int(input("나이 입력: "))

if age > 19 and age < 65:
    print("하반기 일정 확인")
else:
    year_num = int(input("출생 연도 끝자리 입력: "))
    
    if year_num == 1 or year_num == 6:
        print("월요일 접종 가능!!")
    elif year_num == 2 or year_num == 7:
        print("화요일 접종 가능!!")
    elif year_num == 3 or year_num == 8:
        print("수요일 접종 가능!!")
    elif year_num == 4 or year_num == 9:
        print("목요일 접종 가능!!")
    elif year_num == 5 or year_num == 0:
        print("금요일 접종 가능!!")
    else:
        print("다시 입력해 주세요.")
# Out:
# 나이 입력: 17
# 출생 연도 끝자리 입력: 2
# 화요일 접종 가능!!

# %% [markdown]
# - 길이(mm)를 입력하면 inch로 환산하는 프로그램을 만들어보자.(1mm = 0.039inch)

# %%
length = int(input("길이(mm) 입력: "))
inch = 0.039
print(f"{length}mm -> {length * inch}inch")
# Out:
# 길이(mm) 입력: 509
# 509mm -> 19.851inch

# %% [markdown]
# # 53_[연습문제] 조건문(01)

# %% [markdown]
# - 교통 과속 위반 프로그램을 만들어보자.

# %%
speed = int(input("속도 입력: "))

if speed <= 50:
    print("안전속도 준수!!")
    
else:
    print("안전속도 위반!! 과태료 50,000원 부과 대상!!")
# Out:
# 속도 입력: 90
# 안전속도 위반!! 과태료 50,000원 부과 대상!!

# %% [markdown]
# - 문자 메시지 길이에 따라 문자 요금이 결정되는 프로그램을 만들어보자.

# %%
message = str(input("메시지 입력: "))
m_price = 0


if len(message) <= 50:
    m_price = 50
    print("SMS 발송!!")
    
if len(message) > 50:
    m_price = 100
    print("MMS 발송!!")
    
print(f"메시지 길이: {len(message)}")
print(f"메시지 발송 요금: {m_price}원")
# Out:
# 메시지 입력: 안녕하세요.
# SMS 발송!!
# 메시지 길이: 6
# 메시지 발송 요금: 50원

# %% [markdown]
# # 54_[연습문제] 조건문(02)

# %% [markdown]
# - 국어, 영어, 수학, 과학, 국사 점수를 입력하면 총점을 비롯한 각종 데이터가 출력되는
# 프로그램을 만들어보자.

# %% [markdown]
# # abs() - 절댓값 표현

# %%
# 과목별 평균값들의 값 정의
kor_avg = 85; eng_avg = 82; mat_avg = 89; sci_avg = 75; kor_s_avg = 94;
total_avg = kor_avg + eng_avg + mat_avg + sci_avg + kor_s_avg
avg_avg = total_avg // 5

# 과목별 점수 입력
kor = int(input("국어 점수: "))
eng = int(input("영어 점수: "))
mat = int(input("수학 점수: "))
sci = int(input("과학 점수: "))
kor_s = int(input("국사 점수: "))

# 입력받은 과목별 값 정의
sub = [kor, eng, mat, sci, kor_s]
total = sum(sub)
avg = total // len(sub)

# 각 과목의 점수와 표준편차의 차
kor_gap = kor - kor_avg
eng_gap = eng - eng_avg
mat_gap = mat - mat_avg
sci_gap = sci - sci_avg
kor_s_gap = kor_s - kor_s_avg
total_gap = total - total_avg
avg_gap = avg - avg_avg

# 출력
print("-" * 65)
print(f"총점: {total}({total_gap}), 평균: {avg}({avg_gap})")
print(f"국어: {kor}({kor_gap}), 영어: {eng}({eng_gap}), 수학: {mat}({mat_gap}), 과학: {sci}({sci_gap}), 국사: {kor_s}({kor_s_gap}) ")
print("-" * 65)
str = "+" if kor_gap > 0 else "-"
print(f"국어 편차: {str * abs(kor_gap)}({kor_gap})")
str = "+" if eng_gap > 0 else "-"
print(f"영어 편차: {str * abs(eng_gap)}({eng_gap})")
str = "+" if mat_gap > 0 else "-"
print(f"수학 편차: {str * abs(mat_gap)}({mat_gap})")
str = "+" if sci_gap > 0 else "-"
print(f"과학 편차: {str * abs(sci_gap)}({sci_gap})")
str = "+" if kor_s_gap > 0 else "-"
print(f"국사 편차: {str * abs(kor_s_gap)}({kor_s_gap})")
str = "+" if total_gap > 0 else "-"
print(f"총점 편차: {str * abs(total_gap)}({total_gap})")
str = "+" if avg_gap > 0 else "-"
print(f"평균 편차: {str * abs(avg_gap)}({avg_gap})")
print("-" * 65)
# Out:
# 국어 점수: 91
# 영어 점수: 92
# 수학 점수: 61
# 과학 점수: 58
# 국사 점수: 90
# -----------------------------------------------------------------
# 총점: 392(-33), 평균: 78(-7)
# 국어: 91(6), 영어: 92(10), 수학: 61(-28), 과학: 58(-17), 국사: 90(-4)
# -----------------------------------------------------------------
# 국어 편차: ++++++(6)
# 영어 편차: ++++++++++(10)
# 수학 편차: ----------------------------(-28)
# 과학 편차: -----------------(-17)
# 국사 편차: ----(-4)
# 총점 편차: ---------------------------------(-33)
# 평균 편차: -------(-7)
# -----------------------------------------------------------------

# %% [markdown]
# # 55_[연습문제] 조건문(03)

# %% [markdown]
# - 난수를 이용해서 홀/짝 게임을 만들어보자.

# %%
import random

random_num = random.randint(1, 2)
select_num = int(input("홀/짝 선택 1.홀\t 2.짝"))

if random_num == 1 and select_num == 1:
    print("빙고!! 홀수!!")
elif random_num == 2 and select_num == 2:
    print("빙고!! 짝수!!")
elif random_num == 1 and select_num == 2:
    print("실패!! 홀수!!")
elif random_num == 2 and select_num == 1:
    print("실해!! 짝수!!")
# Out:
# 홀/짝 선택 1.홀	 2.짝2
# 빙고!! 짝수!!

# %% [markdown]
# - 난수를 이용해서 가위, 바위, 보 게임을 만들어보자.

# %%
import random

com_num = random.randint(1, 3)
user_num = int(input("1.가위 2.바위 3.보 "))

if (com_num == 1 and user_num == 2) or \
    (com_num == 2 and user_num == 3) or \
    (com_num == 3 and user_num == 1):
    print("컴퓨터: 패, 유저: 승")
elif com_num == user_num:
    print("무승부")
else:
    print("컴퓨터: 승, 유저: 패")
print(f"컴퓨터: {com_num}, 유저: {user_num}")
# Out:
# 1.가위 2.바위 3.보 2
# 컴퓨터: 패, 유저: 승
# 컴퓨터: 1, 유저: 2

# %% [markdown]
# # 56_[연습문제] 조건문(04)

# %% [markdown]
# - 아래 요금표를 참고해서 상수도 요금 계산기를 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.13.25.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.13.25.png)

# %%
# 사용자 입력
select = int(input("업종 선택(1.가정용  2.대중탕용  3.공업용): "))
use = int(input("사용량 입력: "))
unit_price = 0

# 단가 계산기
if select == 1:
    unit_price = 540
elif select == 2:
    if use <= 50:
        unit_price = 820
    elif (use > 50) and (use <= 300):
        unit_price = 1920
    elif use > 300:
        unit_price = 2400
elif select == 3:
    if use <= 500:
        unit_price = 240
    else:
        unit_price = 570
else:
    print("다시 입력해 주세요.")

# 요금 정의
fare = use * unit_price

# 출력
print("="*30,"\n상수도 요금표")
print("-"*30,"\n사용량\t:\t요금")
print(f"{use}\t:\t{fare:,}원")
print("="*30)
# Out:
# 업종 선택(1.가정용  2.대중탕용  3.공업용): 2
# 사용량 입력: 270
# ...
# 상수도 요금표
# ------------------------------
# 사용량	:	요금
# 270	:	518,400원
# ...

# %% [markdown]
# # 57_[연습문제] 조건문(05)

# %% [markdown]
# - 미세먼지 비상저감조치로 차량 운행제한 프로그램을 다음 내용에 맞게 만들어 보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.37.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.37.55.png)

# %%
import datetime

now = datetime.datetime.now()
day = now.day
limit_dust = 150

# 입력
dust = int(input("미세먼지 수치 입력: "))
car = int(input("차량 종류 선택. 1.승용차\t 2.영업용차 " ))
car_num = int(input("차량 변호 입력: "))

# 출력
print("-"*30)
print(now)
print("-"*30)

if dust > limit_dust and car == 1:
    if (day % 2) == (car_num % 2):
        print("차량 2부제 적용")
        print("차량 2부제로 금일 운행제한 대상 차량입니다.")
    else:
        print("금일 운행 가능합니다.")
    
if dust > limit_dust and car == 2:
    if (day % 5) == (car_num  % 5):
        print("차량 5부제 적용")
        print("차량 5부제로 금일 운행제한 대상 차량입니다.")
    else:
        print("금일 운행 가능합니다.")

if dust <= limit_dust:
    if (day % 5) == (car_num  % 5):
        print("차량 5부제 적용")
        print("차량 5부제로 금일 운행제한 대상 차량입니다.")
    else:
        print("금일 운행 가능합니다.")
print("-"*30)
# Out:
# 미세먼지 수치 입력: 145
# 차량 종류 선택. 1.승용차	 2.영업용차 1
# 차량 변호 입력: 5526
# ------------------------------
# 2023-07-09 01:43:43.369998
# ------------------------------
# 금일 운행 가능합니다.
# ------------------------------

# %% [markdown]
# # 58_[연습문제] 조건문(06)

# %% [markdown]
# - PC에서 난수를 발생하면 사용자가 맞추는 게임을 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.05.15.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.05.15.png)

# %%
import random

random_num = random.randint(1, 10)
try_cnt = 0
flag = True

while flag:
    try_cnt += 1
    user_num = int(input("1에서 10까지의 정수 입력: "))
    
    if random_num == user_num:
        print("빙고")
        flag = False
    else:
        if random_num > user_num:
            print("난수가 크다!")
        else:
            print("난수가 작다!")

print(f"난수: {random_num}, 시도 횟수: {try_cnt}")
# Out:
# 1에서 10까지의 정수 입력: 4
# 난수가 크다!
# 1에서 10까지의 정수 입력: 6
# 난수가 크다!
# 1에서 10까지의 정수 입력: 8
# 난수가 작다!
# 1에서 10까지의 정수 입력: 7
# 빙고
# 난수: 7, 시도 횟수: 4

# %% [markdown]
# - 실내온도를 입력하면 스마트에어컨 상태가 자동으로 설정되는 프로그램을 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.05.40.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.05.40.png)

# %%
temp = int(input("실내온도 입력: "))
status = ""

if temp <= 18:
    status = "OFF"
elif temp > 18 and temp <= 22:
    status = "매우 약"
elif temp > 22 and temp <= 24:
    status = "약"
elif temp > 24 and temp <= 26:
    status = "중"
elif temp > 26 and temp <= 28:
    status = "강"
else:
    status = "매우 강"
    
print(f"에어컨: {status}")
# Out:
# 실내온도 입력: 14
# 에어컨: OFF

# %% [markdown]
# # 59_[연습문제] 반복문(01)

# %% [markdown]
# -  1부터 100까지 정수 중 십의자리와 일의자리에 대해 각각 홀/짝수를 구분하는 프로그램을 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2011.32.13.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2011.32.13.png)

# %%
for i in range(1, 101):
    
    # i가 1자릿수 일때
    if i < 10:
        if i % 2 == 0:
            print(f"[{i}]: 짝수!")
        else:
            print(f"[{i}]: 홀수!")
    # i가 2자릿수 이상일때        
    else:
        # 십의 자리가 짝수인 수
        if int(str(i)[-2]) % 2 == 0:
            if int(str(i)[-1]) == 0:
                print(f"[{i}] 십의자리: 짝수!!, 일의자리: 0")
            else:
                if int(str(i)[-1]) % 2 == 0:
                    print(f"[{i}] 십의자리: 짝수!!, 일의자리: 짝수")
                else:
                    print(f"[{i}] 십의자리: 짝수!!, 일의자리: 홀수")
            
        # 십의 자리가 홀수인 수
        else:
            if int(str(i)[-1]) == 0:
                print(f"[{i}] 십의자리: 홀수!!, 일의자리: 0")
            else:
                if int(str(i)[-1]) % 2 == 0:
                    print(f"[{i}] 십의자리: 홀수!!, 일의자리: 짝수")
                else:
                    print(f"[{i}] 십의자리: 홀수!!, 일의자리: 홀수")
# Out:
# [1]: 홀수!
# [2]: 짝수!
# [3]: 홀수!
# [4]: 짝수!
# [5]: 홀수!
# [6]: 짝수!
# [7]: 홀수!
# [8]: 짝수!
# [9]: 홀수!
# [10] 십의자리: 홀수!!, 일의자리: 0
# [11] 십의자리: 홀수!!, 일의자리: 홀수
# [12] 십의자리: 홀수!!, 일의자리: 짝수
# [13] 십의자리: 홀수!!, 일의자리: 홀수
# [14] 십의자리: 홀수!!, 일의자리: 짝수
# [15] 십의자리: 홀수!!, 일의자리: 홀수
# [16] 십의자리: 홀수!!, 일의자리: 짝수
# [17] 십의자리: 홀수!!, 일의자리: 홀수
# [18] 십의자리: 홀수!!, 일의자리: 짝수
# [19] 십의자리: 홀수!!, 일의자리: 홀수
# [20] 십의자리: 짝수!!, 일의자리: 0
# [21] 십의자리: 짝수!!, 일의자리: 홀수
# [22] 십의자리: 짝수!!, 일의자리: 짝수
# [23] 십의자리: 짝수!!, 일의자리: 홀수
# [24] 십의자리: 짝수!!, 일의자리: 짝수
# [25] 십의자리: 짝수!!, 일의자리: 홀수
# [26] 십의자리: 짝수!!, 일의자리: 짝수
# [27] 십의자리: 짝수!!, 일의자리: 홀수
# [28] 십의자리: 짝수!!, 일의자리: 짝수
# [29] 십의자리: 짝수!!, 일의자리: 홀수
# [30] 십의자리: 홀수!!, 일의자리: 0
# [31] 십의자리: 홀수!!, 일의자리: 홀수
# [32] 십의자리: 홀수!!, 일의자리: 짝수
# [33] 십의자리: 홀수!!, 일의자리: 홀수
# [34] 십의자리: 홀수!!, 일의자리: 짝수
# [35] 십의자리: 홀수!!, 일의자리: 홀수
# [36] 십의자리: 홀수!!, 일의자리: 짝수
# [37] 십의자리: 홀수!!, 일의자리: 홀수
# [38] 십의자리: 홀수!!, 일의자리: 짝수
# [39] 십의자리: 홀수!!, 일의자리: 홀수
# [40] 십의자리: 짝수!!, 일의자리: 0
# [41] 십의자리: 짝수!!, 일의자리: 홀수
# ...

# %% [markdown]
# # 60_[연습문제] 반복문(02)

# %% [markdown]
# - 1부터 사용자가 입력한 정수까지의 합, 홀수의 합, 짝수의 합 그리고 팩토리얼을 출력하는 프로그램을 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.04.30.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.04.30.png)

# %%
num = int(input("정수 입력: "))
total = 0
odd_total = 0
even_total = 0
factorial = 1

for i in range(1, num+1):
    total += i
    factorial *= i
    if i % 2 == 0:
        even_total += i
    else:
        odd_total += i

print(f"합 결과 : {total}")
print(f"홀수 합 결과 : {odd_total}")
print(f"짝수 합 결과 : {even_total}")
print(f"팩토리얼 결과 : {factorial:,}")
# Out:
# 정수 입력: 15
# 합 결과 : 120
# 홀수 합 결과 : 64
# 짝수 합 결과 : 56
# 팩토리얼 결과 : 1,307,674,368,000

# %% [markdown]
# # 61_[연습문제] 반복문(03)

# %% [markdown]
# - ‘ * ’를 이용해서 다음과 같이 다양한 모양을 출력해보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.13.08.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.13.08.png)

# %%
# 1
for i in range(1, 6):
    print("*" * i)

# 2 중첩문
for i in range(1, 6):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# *
# **
# ***
# ****
# *****

# %%
# 1
for i in range(1, 6):
    print(" " * (5-i), "*" * i)

# 2 중첩문
for i in range(1, 6):
    for j in range(6 - i - 1):
        print(" ", end="")
    for k in range(i):
        print("*", end="")
    print()
# Out:
#      *
#     **
#    ***
#   ****
#  *****
#     *
#    **
#   ***
#  ****
# *****

# %%
# 1
for i in range(5, 0, -1):
    print("*" * i)

# 중첩문
for i in range(5, 0, -1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *
# *****
# ****
# ***
# **
# *

# %%
# 1
for i in range(5, 0, -1):
    print(" " * (5-i), "*" * i)

# 중첩문
for i in range(5, 0, -1):
    for j in range(5 - i):
        print(" ", end="")
    for j in range(i):
        print("*", end="")
    print()
# Out:
#  *****
#   ****
#    ***
#     **
#      *
# *****
#  ****
#   ***
#    **
#     *

# %%
# 1
for i in range(1, 6):
    print("*" * i)
for i in range(5, 0, -1):
    print("*" * i)
    
# 2
for i in range(1, 10):
    if i < 5:
        for j in range(i):
            print("*", end="")
    else:
        for j in range(10 - i):
            print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# *****
# ****
# ***
# **
# *
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
# 1
for i in range(1, 6):
    print(" " * (i-1), "*")

# 중첩문
for i in range(1, 6):
    for j in range(1, 6):
        if j == i:
            print("*", end="")
        else:
            print(" ", end="")
    print()
# Out:
#  *
#   *
#    *
#     *
#      *
# *
#  *
#   *
#    *
#     *

# %%
for i in range(1, 6):
    print(" " * (5-i), "*")
# Out:
#      *
#     *
#    *
#   *
#  *

# %%
n = 5
for i in range(1, n+1):
    print(" " * (5-i), "*" * ((i*2) - 1))
for i in range(n, 0, -1):
    print(" " * (5-i), "*" * ((i*2) - 1))
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
#  *********
#   *******
#    *****
#     ***
#      *

# %% [markdown]
# # 62_[연습문제] 반복문(04)

# %% [markdown]
# - 집 앞 버스 정류장에서 학교까지 가는 버스 A, B, C 의 운행정보가 다음과 같을 때,
# - 2대 이상의 버스가 정차하는 시간대를 출력해보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.39.09.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.39.09.png)

# %%
import datetime

bus_a = 15
bus_b = 13
bus_c = 8

total_min = 60 * 17

for i in range(total_min + 1):
    if i < 20 or i > (total_min - 60):
        if i % bus_a == 0 and i % bus_b == 0:
            print("bus_A와 bus_B 동시 정차!", end=" ")
            hour = 6 + i // 60
            min = i % 60
            print(f"{hour}:{min}")
    else:
        if i % bus_a == 0 and i % bus_b == 0:
            print("bus_A와 bus_B 동시 정차!", end=" ")
            hour = 6 + i // 60
            min = i % 60
            print(f"{hour}:{min}")
        elif i % bus_a == 0 and i % bus_c == 0:
            print("bus_A와 bus_c 동시 정차!", end=" ")
            hour = 6 + i // 60
            min = i % 60
            print(f"{hour}:{min}")
        elif i % bus_b == 0 and i % bus_c == 0:
            print("bus_B와 bus_c 동시 정차!", end=" ")
            hour = 6 + i // 60
            min = i % 60
            print(f"{hour}:{min}")
# Out:
# bus_A와 bus_B 동시 정차! 6:0
# bus_B와 bus_c 동시 정차! 7:44
# bus_A와 bus_c 동시 정차! 8:0
# bus_A와 bus_B 동시 정차! 9:15
# bus_B와 bus_c 동시 정차! 9:28
# bus_A와 bus_c 동시 정차! 10:0
# bus_B와 bus_c 동시 정차! 11:12
# bus_A와 bus_c 동시 정차! 12:0
# bus_A와 bus_B 동시 정차! 12:30
# bus_B와 bus_c 동시 정차! 12:56
# bus_A와 bus_c 동시 정차! 14:0
# bus_B와 bus_c 동시 정차! 14:40
# bus_A와 bus_B 동시 정차! 15:45
# bus_A와 bus_c 동시 정차! 16:0
# bus_B와 bus_c 동시 정차! 16:24
# bus_A와 bus_c 동시 정차! 18:0
# bus_B와 bus_c 동시 정차! 18:8
# bus_A와 bus_B 동시 정차! 19:0
# bus_B와 bus_c 동시 정차! 19:52
# bus_A와 bus_c 동시 정차! 20:0
# bus_B와 bus_c 동시 정차! 21:36
# bus_A와 bus_c 동시 정차! 22:0
# bus_A와 bus_B 동시 정차! 22:15

# %% [markdown]
# # 63_[연습문제] 반복문(05)

# %% [markdown]
# - 톱니가 각각 n1개와 n2개의 톱니바퀴가 서로 맞물려 회전할 때,
# - 회전을 시작한 후 처음 맞물린 톱니가 최초로 다시 만나게 될 때까지의 톱니의 수와 각각의 바퀴 회전수를 출력해보자.
# - (단, n2는 n1보다 크다.)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.57.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.57.20.png)

# %%
gear_a = int(input("GearA 톱니수 입력: "))
gear_b = int(input("GearB 톱니수 입력: "))
min_mul = 0

for i in range(max(gear_a, gear_b), (gear_a * gear_b) + 1):
    if i % gear_a == 0 and i % gear_b == 0:
        min_mul = i
        break

print(f"최초 만나는 톱니수(최소공배수): {min_mul}톱니")
print(f"gear_A 회전수: {min_mul // gear_a}회전")
print(f"gear_B 회전수: {min_mul // gear_b}회전")
# Out:
# GearA 톱니수 입력: 7
# GearB 톱니수 입력: 12
# 최초 만나는 톱니수(최소공배수): 84톱니
# gear_A 회전수: 12회전
# gear_B 회전수: 7회전

# %% [markdown]
# # 64_[연습문제] 반복문(06)

# %% [markdown]
# - 윤년 계산기를 만들어보자.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.16.04.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-09%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.16.04.png)

# %%
year = int(input("연도 입력: "))

# 1.
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print(f"{year}년: 윤년!!")
else:
    print(f"{year}: 평년")

# 2. for문
for year in range(year, year + 51):
    if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
        print(f"{year}년: 윤년!!")
    else:
        print(f"{year}: 평년")
# Out:
# 연도 입력: 2024
# 2024년: 윤년!!
# 2025: 평년
# 2026: 평년
# 2027: 평년
# 2028년: 윤년!!
# 2029: 평년
# 2030: 평년
# 2031: 평년
# 2032년: 윤년!!
# 2033: 평년
# 2034: 평년
# 2035: 평년
# 2036년: 윤년!!
# 2037: 평년
# 2038: 평년
# 2039: 평년
# 2040년: 윤년!!
# 2041: 평년
# 2042: 평년
# 2043: 평년
# 2044년: 윤년!!
# 2045: 평년
# 2046: 평년
# 2047: 평년
# 2048년: 윤년!!
# 2049: 평년
# 2050: 평년
# 2051: 평년
# 2052년: 윤년!!
# 2053: 평년
# 2054: 평년
# 2055: 평년
# 2056년: 윤년!!
# 2057: 평년
# 2058: 평년
# 2059: 평년
# 2060년: 윤년!!
# 2061: 평년
# 2062: 평년
# 2063: 평년
# 2064년: 윤년!!
# 2065: 평년
# 2066: 평년
# 2067: 평년
# 2068년: 윤년!!
# 2069: 평년
# 2070: 평년
# 2071: 평년
# 2072년: 윤년!!
# 2073: 평년
# 2074: 평년
