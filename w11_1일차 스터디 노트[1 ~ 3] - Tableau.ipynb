# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.35.31.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.35.31.png)

# %% [markdown]
# # 1. Unit 1

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.55.23.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.55.23.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # inner join

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.27.03.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.27.03.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 차원(상단) / 측정값(하단)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.44.03.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-09-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.44.03.png)

# %% [markdown]
# 불연속성은 차트에서 머리끌을 표시
# 연속성은 차트에서 축을 표시한다.

# %% [markdown]
# ## 2. Unit 2 ~ 3
