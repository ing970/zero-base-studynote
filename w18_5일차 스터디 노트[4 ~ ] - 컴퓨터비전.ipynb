# %% [markdown]
# # 1. OpenCV 기초 사용법_1

# %% [markdown]
# ## 📍 영상 데이터의 속성

# %% [markdown]
# ### ⚡️ OpenCV는 영상 데이터를 numpy.ndarray로 표현
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.58.17.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.58.17.png)

# %% [markdown]
# ### ⚡ OpenCV 영상 데이터 자료형과 NumPy 자료형
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.59.59.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.59.59.png)

# %% [markdown]
# ### ⚡ 영상의 속성 참조 예제

# %%
img1 = cv2.imread("cat.jpeg", cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("cat.jpeg", cv2.IMREAD_COLOR)

print(img1.shape) # (138, 92)
print(img2.shape) # (138, 92, 3)
print(img1.dtype) # uint8
print(type(img1)) # <class 'numpy.ndarray'>

h, w = img2.shape[:2]
print("img2 size: {} x {}".format(w, h)) # img2 size: 92 x 138

if len(img1.shape) == 2:
    print("img1 is a grayscale image")
elif len(img1.shape) == 3:
    print("img1 is a truecolor image")
# Out:
# (138, 92)
# (138, 92, 3)
# uint8
# <class 'numpy.ndarray'>
# img2 size: 92 x 138
# img1 is a grayscale image

# %% [markdown]
# ## 📍 영상의 생성과 복사

# %% [markdown]
# ### ⚡ 새 영상 생성하기
# - shape: 각 차원의 크기. (h, w) 또는 (h, w, 3)
# - dtype: 원소의 데이터 타입. 일반적인 영상이면 numpy.unit8 지정
# - arr: 생성된 영상(numpy.ndarray)
# - 참고사항
#     - numpy.empty( ) 함수는 임의의 값으로 초기화된 배열을 생성
#     - numpy.zeros( ) 함수는 0으로 초기화된 배열을 생성
#     - numpy.ones( ) 함수는 1로 초기화된 배열을 생성
#     - numpy.full( ) 함수는 fill_value로 초기화된 배열을 생성
#
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.13.42.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.13.42.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.14.45.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.14.45.png)

# %% [markdown]
# ## 📍부분 영상 다루기

# %% [markdown]
# ### ⚡ 부분 영상 참조와 복사

# %%
img1 = cv2.imread("cat.jpeg")


img2 = img1[20:70, 20:70] # numpy.ndarray의 슬라이싱
img3 = img1[20:70, 20:70].copy()

img2.fill(0)

f, ax = plt.subplots(1, 3)

ax[0].imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
ax[1].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
ax[2].imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

plt.show()

# %% [markdown]
# ### ⚡ 부분 영상에 대한 처리

# %%
img = cv2.imread("cat.jpeg", cv2.IMREAD_GRAYSCALE)

 # 얼굴영역
img_face1 = img[20:70, 20:70]

# 밝기 조절
img_face2 = cv2.add(img_face1, 50, img_face2)

f, ax = plt.subplots(1, 2)

ax[0].imshow(img_face1, cmap="gray")
ax[1].imshow(img_face2, cmap="gray")
plt.show()

# %% [markdown]
# ## 📍 마스크 연산과 ROI

# %% [markdown]
# ### ⚡ 관심 영역(ROI)
# - Region of Interest
# - 영상에서 특정 연산을 수행하고자 하는 임의의 부분 영역
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.40.10.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.40.10.png)

# %% [markdown]
# ### ⚡ 마스크 연산
# - OpenCV는 일부 함수에 대해 ROI 연산을 지원하며, 이때 마스크 영상을 인자로 함께 전달해야한다.
# - 마스크 영상은 "cv2.CV_8UC1" 타입(그레이스케일 영상)
# - 마스크 영상의 픽셀 값이 0이 아닌 위치에서만 연산이 수행된다.
#     - 보통 마스크 영상으로는 0 또는 255로 구성된 이진 영상(binary image)을 사용한다.

# %% [markdown]
# ### ⚡ 마스크 연산을 지원하는 픽셀 값 복사 함수
# - src: 입력 영상
# - mask: 마스크 영상 cv2.CV_8U(numpy.unit8) 0이 아닌 픽셀에 대해서만 복사 연산을 수행한다.
# - dst: 출력 영상이 만약 src와 크기 및 타입이 같은 dst를 입력으로 지정하면 dst를 새로 생성하지 않고 연산을 수행한다. 그렇지 않으면 dst를 새로 생성하여 연산을 수행한 후 반환한다.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.48.05.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.48.05.png)

# %% [markdown]
# ### ⚡ 마스크 연산 예제
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.58.33.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.58.33.png)

# %% [markdown]
# ### ⚡ Numpy의 불리언 인덱싱을 이용한 마스크 연산
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.59.56.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.59.56.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.00.35.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.00.35.png)

# %% [markdown]
# ## 📍 투명한 PNG 파일 합성하기
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.02.51.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.02.51.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.03.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.03.22.png)

# %% [markdown]
# # 2. OpenCV 기초 사용법_2

# %% [markdown]
# ## 📍 OpenCV 그리기 함수
# - OpenCV는 영상에 선, 도형, 문자열을 출력하는 그리기 함수를 제공
# - 선 그리기: 직선, 화살표, 마커등
# - 도형 그리기: 사각형, 원, 타원, 다각형등
# - 문자열 출력

# %% [markdown]
# ### ⚡ 그리기 함수 사용 시 주의할 점
# - 그리기 알고리즘을 이용하여 영상의 픽셀 값 자체를 변경
#     - 원본 영상이 필요하면 복사본을 만들어서 그리기 & 출력
# - 그레이스케일 영상에는 컬러로 그리기 안 됨
#     - cv2.cvtColor( ) 함수를 BGR 컬러 영상으로 변환한 후 그리기 함수 호출

# %% [markdown]
# ### ⚡ OpenCV 주요 그리기 함수
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.09.25.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-11-08%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%208.09.25.png)

# %% [markdown]
# ### ⚡ 직선 그리기

# %% [markdown]
# ### ⚡

# %% [markdown]
# ### ⚡

# %% [markdown]
# ### ⚡

# %% [markdown]
# ### ⚡

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍## 📍

# %% [markdown]
# ## 📍

# %% [markdown]
# ## 📍

# %%
##
