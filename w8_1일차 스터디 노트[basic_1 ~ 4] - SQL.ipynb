# %% [markdown]
# # ⚡️study by 석민⚡️

# %% [markdown]
# ### 데이터 정의 언어 (DDL: Data Definition Language)
#     - CREATE, ALTER, DROP 등의 명령어
# ### 데이터 조작 언어 (DML: Data Manipulation Language)
#     - INSERT, UPDATE, DELETE, SELECT 등의 명령어
# ### 데이터 제어 언어 (DCL: Data Control Language)
#     - GRANT, REVOKE, COMMIT, ROLLBACK 등의 명령어

# %% [markdown]
# # 1. 데이터베이스 및 권한 관리

# %% [markdown]
# ### 데이터베이스 생성 및 삭제
#
# ~~~mysql
# SHOW DATABASES;
# CREATE DATABASE testedb;
# USE testdb;
# DROP DATABASE testdb;
# SHOW DATABASES;
# ~~~

# %% [markdown]
# ~~~mysql
# USE mysql;
#
# SELECT host, user FROM user;
# ~~~

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.47.03.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.47.03.png)

# %% [markdown]
# ~~~mysql
# CREATE USER 'seokmin'@'localhost' identified by '1234';
# ~~~
#
# - 외부에서 접속 가능한 사용자를 비밀번호와 함께 생성
# ~~~mysql
# CREATE USER 'seokmin'@'%' identified by '1234';
# ~~~

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.41.43.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.41.43.png)

# %% [markdown]
# ## ❗️ error 메모

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.14.57.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.14.57.png)

# %% [markdown]
# - 해당 오류는 MySQL 또는 MariaDB에서 비밀번호를 설정할 때 해당 비밀번호가 서버의 비밀번호 정책을 충족하지 않을 때 발생합니다

# %% [markdown]
# ~~~mysql
# SET GLOBAL validate_password_length=4;
# ~~~

# %%
DROP USER 'seokmin'@'localhost';
DROP USER 'seokmin'@'%';

# %%
SHOW GRANTS FOR 'noma'@'localhost';

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.01.02.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.01.02.png)

# %% [markdown]
# ### 사용자에게 특정 데이터베이스 권한 부여

# %%
GRANT ALL ON dbname.* TO 'noma'@'localhost';
SHOW GRANTS FOR 'noma'@'localhost';

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.11.56.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.11.56.png)

# %% [markdown]
# ### 사용자에게 특정 데이터베이스 권한 삭제

# %%
REVOKE ALL ON dbname.* FROM 'noma'@'localhost';
SHOW GRANTS FOR 'noma'@'localhost';
# Out:
#   Cell In[5], line 1
#     REVOKE ALL ON dbname.* FROM 'noma'@'localhost';
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.16.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.16.20.png)

# %% [markdown]
# ### ❗️ 수정내용이 적용이 되지 않은 경우 새로 고침
# FLUSH PRIVILEGES;

# %% [markdown]
# # 2. Table 생성과 변경 및 삭제

# %%
CREATE DATABASE zerobase DEFAULT CHARACTER SET utf8mb4;
USE zerobase;

# %%
CREATE TABLE zero (id INT, name VARCHAR(16));
SHOW TABLES;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.05.31.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.05.31.png)

# %% [markdown]
# ### 테이블 정보 확인

# %%
DESC zero;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.06.01.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.06.01.png)

# %%
# 테이블 이름 수정
# ALTER TABLE 수정할 테이블이름  // RENAME  테이블이름
ALTER TABLE tablename RENAME new_tablename;

# 테이블의 컬럼 추가
# ALTER TABLE 수정할 테이블이름  // ADD COLUMN 컬럼이름 컬럼타입
ALTER TABLE tablename ADD COLUMN column name datatype;

# 테이블의 컬럼 데이터타입 수정
# ALTER TABLE 수정할 테이블이름  // MODIFY COLUMN 컬럼이름 컬럼타입
ALTER TABLE tablename MODIFY COLUMN column name datatype;

# 테이블의 컬럼이름 수정
# ALTER TABLE 수정할 테이블이름 // CHANGE COLUMN 바꿀이름 바뀔이름 데이터타입
ALTER TABLE tablename CHANGE COLUMN old_name new_name datatype;

# 테이블의 컬럼 삭제
# ALTER TABLE 수정할 테이블이름 // DROP COLUMN 삭제할 컬럼이름
ALTER TABLE tablename DROP COLUMN columnname;
# Out:
#   Cell In[6], line 2
#     ALTER TABLE tablename RENAME new_tablename;
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 3. DML - 데이터 조작 언어

# %% [markdown]
# ### INSERT: 데이터추가

# %%
INSERT INTO tablename (col1, col2)
VALUES (data1, data2)

# 모든 컬럼값을 추가하는 경우 -> 컬럼 이름 지정 X
# 하지만 입력하는 값의 순서가 테이블의 컬럼 순서와 일치하도록 주의
INSERT INTO tablename
VALUES (data, data, data...);



INSERT INTO person(id, name, age)
VALUES (1, 유재석, 45)

# %% [markdown]
# ### SELECT: 데이터 조회

# %%
SELECT col
FROM tablename;


SELECT * FROM person;

# %% [markdown]
# ### UPDATE: 데이터 수정

# %%
UPDATE person
SET col1=value1
WHERE 조건;


UPDATE table
SET age=50
WHERE name='유재석';

# %% [markdown]
# ### DELETE: 데이터 삭제

# %%
DELETE FROM tablename
WHERE 조건;

DELETE FROM person
WHERE name='유재석';

# %% [markdown]
# # 3. ORDER BY

# %% [markdown]
# - ASC(Ascending): 오름차순으로 정렬
# - DESC(Descending): 내림차순으로 정렬

# %%
SELECT col1
FROM tablename
ORDER BY col1 DESC; # or ASC;
# Out:
#   Cell In[15], line 1
#     SELECT *
#             ^
# SyntaxError: invalid syntax
