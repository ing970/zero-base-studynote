# %% [markdown]
# # ⚡️study by 석민⚡️

# %% [markdown]
# # 66_[연습문제] 텍스트파일(02)

# %% [markdown]
# - 텍스트 파일에 수입과 지출을 기록하는 가계부를 만들어보자.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.44.08.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.44.08.png)

# %% [markdown]
# # 67_[연습문제] 텍스트파일(03)

# %% [markdown]
# - 사용자가 입력한 숫자까지의 소수를 텍스트 파일에 기록해 보자.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.45.59.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.45.59.png)

# %% [markdown]
# # 68_[연습문제] 텍스트파일(04)

# %% [markdown]
# - 두 개의 수를 입력하면 최대공약수를 텍스트 파일에 작성해보자.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.47.05.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-07-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.47.05.png)

# %% [markdown]
# # 69_[연습문제] 텍스트파일(05)

# %% [markdown]
# -

# %% [markdown]
# # 01_약수와 소수

# %% [markdown]
# # 02_약수와 소수(파이썬)

# %% [markdown]
# # 03_소인수와 소인수분해

# %% [markdown]
# # 04_소인수와 소인수분해(파이썬)

# %% [markdown]
# # 05_최대공약수

# %% [markdown]
# # 06_최대공약수(파이썬)

# %% [markdown]
# # 07_최소공배수

# %% [markdown]
# # 08_최소공배수(파이썬)

# %% [markdown]
# # 09_진법

# %% [markdown]
# # 10_진법(파이썬)

# %% [markdown]
# # 11_수열

# %% [markdown]
# # 12_등차 수열

# %% [markdown]
# # 13_등차 수열(파이썬) (01)
