# %% [markdown]
# # ⚡️study by 석민⚡️

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.27.50.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.27.50.png)

# %% [markdown]
# # 1. 심화1

# %% [markdown]
# ## 외부에서 접속
# - 터미널 실행
# ~~~mysql
# % mysql -h <엔드포인트> -P <포트> -u <마스터 사용자 이름> -p
# ~~~

# %%
# AWS RDS에서 데이터베이스 생성할때 만든 USER id 와 USER 패스워드 입력하고 접속
mysql -h 엔드포인트 -P 3306 -u admin -p

# %%
# 외부에서 RDS 접속 후 데이터 베이스 생성
CREATE DATABASE zerobase;
USE zerobase;

# %%
# USER 생성
CREATE USER 'zero'@'%' identified by '1234';

# %%
# USER 생성 확인
USE mysql;
SELECT host, user FROM user;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.30.00.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.30.00.png)

# %%
# USER 'zero'에 대한 권한이 있는 데이터베이스 목록 확인
SHOW GRANTS FOR 'zero'@'%';

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.30.19.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-28%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.30.19.png)

# %% [markdown]
# - 현재 접속을 종료하고 AWS RDS (database-1)의 zerobase 에 zero 로 접속하세요.

# %%
# admin이 아닌 zero 로 접속
mysql -h 엔드포인트 -P 3306 -u z
ero -p

# %% [markdown]
# # 2. 심화2

# %% [markdown]
# ### 📍SQL 쿼리 파일 실행

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.24.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.24.22.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.27.51.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.27.51.png)

# %% [markdown]
# ## 📍 외부에서 접속하면서 바로 DB 접속
# ~~~command
# mysql -u root -p zerobase
# ~~~

# %% [markdown]
# ## 📍 외부 접속 이후 SQL 쿼리 실행
#  1. 터미널을 통해 쿼리파일이 있는 경로이동
#  2. mysql 접속
#
# ~~~command
# mysql -u root -p
# ~~~

# %%
source test01.sql
DESC police_station;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.27.34.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.27.34.png)

# %% [markdown]
# ## 📍 외부에서 바로 SQL 쿼리 실행
# ~~~command
# mysql -u username -p database < </path/filename.sql>
# ~~~

# %%
mysql -u root -p zerobase < test02.sql

# %%
# mysql 접속 후 확인
DESC crime_status;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.38.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.38.55.png)

# %% [markdown]
# ## 📍 SQL File로 Database를 백업할 수 있다. (dump 하기)
#
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.40.58.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.40.58.png)

# %%
mysqldump -u root -p zerobase > zerobase.sql

# %% [markdown]
# ### 파일 생성 확인

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.45.48.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.45.48.png)

# %% [markdown]
# ### 📍 AWS RDS 외부 접속 이후 dump 파일 올리기

# %%
mysql -h 엔드포인트 -P 3306 -u zero -p
source zerobase.sql
SHOW TABLES;

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.53.16.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.53.16.png)

# %% [markdown]
# ## 📍 Table 단위로도 백업할 수 있다.
# ~~~command
# mysqldump -u username -p dbname tablename > backup.sql
# ~~~

# %%
mysqldump -u root -p zerobase celeb > celeb.sql

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.03.03.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.03.03.png)

# %% [markdown]
# ## 📍 Table Restore
# - Table 을 백업한 SQL File 을 실행하여, 해당 테이블을 복구하거나 이전할 수 있다.
# - SQL File 을 실행하는 방법과 동일함

# %% [markdown]
# - AWS RDS 접속 이후
# - celeb table 삭제 후 다시 올리기
# ~~~mysql
# DROP TABLE celeb;
# SOURCE celeb.sql;
# ~~~

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.09.37.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.09.37.png)

# %% [markdown]
# ## 📍 Table Schema Backup
# - 데이터를 제외하고 테이블 생성 쿼리만 백업할 수 있다.
# - 기본 dump 코드에서 -u 앞에 -d 추가

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.11.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.11.55.png)

# %%
mysqldump -d -u root -p zerobase snl_show > snl_show.sql

# %% [markdown]
# - 내용없이 table만 백업
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.17.11.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.17.11.png)

# %% [markdown]
# ## ❗️AWS RDS database 를 백업할 경우

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.19.15.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-08-29%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%202.19.15.png)

# %% [markdown]
# #### AWS RDS (database-1) zerobase 의 police_station 테이블을 SQL 파일로 백업하세요.

# %%
mysqldump --set-gtid-purged=OFF -h 엔드포인트 -P 3306 -u admin -p zerodb police_station > police_station_backup
.sql
